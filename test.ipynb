# %%
import os
import pandas as pd

# %%
for file in os.listdir('./data'):
    df = pd.read_csv(os.path.join('./data', file), nrows=10)
    print(f"{file}")
    print(len(df))
    print(df.columns)
    print(df.head())
    print()
    print()
# Out:
# category_sample.csv
# 10
# Index(['category_id', 'category_name', 'level', 'parent_category', 'parent_id',
#        'industry_id', 'is_selected'],
#       dtype='object')
#    category_id             category_name  level      parent_category  \
# 0       921000       Nước hoa, Body mist      1                  NaN
# 1       921001   Nước hoa, body mist nam      2  Nước hoa, Body mist
# 2       922001    Nước hoa, body mist nữ      2  Nước hoa, Body mist
# 3       923001  Nước hoa, body mist khác      2  Nước hoa, Body mist
# 4       941000            Trang điểm mặt      1                  NaN
#
#    parent_id  industry_id  is_selected
# 0          0            2            1
# 1     921000            2            1
# 2     921000            2            1
# 3     921000            2            1
# 4          0            2            1
#
#
# holidays_events.csv
# 10
# Index(['date', 'type', 'locale', 'locale_name', 'description', 'transferred'], dtype='object')
# ...
